# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenaSL/PRAVEENASL/blob/main/ASSNMT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as no
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('/content/iris.xls')
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
data.mean()
# Out:
# <ipython-input-6-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
data.isna()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
#BAR DIAGRAM
plt.bar(data['Classification'],data['SL'],color='yellow')
plt.xticks(rotation=360)
plt.title('Classification Table')
plt.xlabel('Classification')
plt.ylabel('SL')
# Out:
# Text(0, 0.5, 'SL')

# %%
#SCATTER
plt.scatter(data['SL'],data['SW'])
plt.title('SCATTER DIAGRAM OF SL AND SW')
plt.xlabel('SL')
plt.ylabel('SW')
# Out:
# Text(0, 0.5, 'SW')

# %%
plt.boxplot(data['SL'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c5a07c21a80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c5a07c21fc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c5a07c217e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c5a07c22500>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c5a07c227a0>],
#  'means': []}
